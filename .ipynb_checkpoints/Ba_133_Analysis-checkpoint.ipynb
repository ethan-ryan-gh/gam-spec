# %%
###################
# Import Libraries
###################

import pandas as pd # coding but excel
import numpy as np # number stuff, creates arrays
import matplotlib.pyplot as plt # plotting
from scipy.optimize import curve_fit # curve fit class
import pprint # PPrint bby


##############
# Import data
##############

df_Ba_133 = pd.read_csv("Ba_133.csv") # create pandas dataframe
print(df_Ba_133.head()) # print first 5 rows


##############
# Plot data
##############

x_Ba_133 = df_Ba_133["Channel"] # grab column
y_Ba_133 = df_Ba_133["Counts"] # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Raw Data Plot")
plt.plot(x_Ba_133, y_Ba_133)
plt.show()

x_Ba_133 = df_Ba_133["Channel"] # grab column
y_Ba_133_log = np.log(df_Ba_133["Counts"]) # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Log Counts")
plt.title("Ba-133 Raw Data Plot (Log)")
plt.plot(x_Ba_133, y_Ba_133_log)
plt.show()

x_Ba_133_slice_01 = df_Ba_133["Channel"][100:400] # grab column
y_Ba_133_slice_01 = df_Ba_133["Counts"][100:400] # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Raw Data Plot (slice)")
plt.plot(x_Ba_133_slice_01, y_Ba_133_slice_01)
plt.show()

x_Ba_133_slice_02 = df_Ba_133["Channel"][400:1000] # grab column
y_Ba_133_slice_02 = df_Ba_133["Counts"][400:1000] # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Raw Data Plot (slice)")
plt.plot(x_Ba_133_slice_02, y_Ba_133_slice_02)
plt.show()

x_Ba_133_slice_03 = df_Ba_133["Channel"][1000:] # grab column
y_Ba_133_slice_03 = df_Ba_133["Counts"][1000:] # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Raw Data Plot (slice)")
plt.plot(x_Ba_133_slice_03, y_Ba_133_slice_03)
plt.show()

x_Ba_133_slice_04 = df_Ba_133["Channel"][1070:] # grab column
y_Ba_133_slice_04 = np.exp(df_Ba_133["Counts"][1070:]) # grab column
plt.figure(figsize=(15,10))
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Raw Data Plot (slice)")
plt.plot(x_Ba_133_slice_04, y_Ba_133_slice_04)
plt.show()
# Out:
#    Channel  Counts
# 0        0       9
# 1        1       0
# 2        2       2
# 3        3       0
# 4        4       0
# /opt/conda/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
################################
# Define the Gaussian function
# takes in constants, solves 
# equation, returns value
################################

def gaus(x, a, mean, sigma, h):
    fit = a*np.exp((-(x-mean)**2)/(2*sigma**2)) + h
    return fit

def dODoubleGaus(x, a1, mean1, sigma1, h, a2, mean2, sigma2):
    fit = a1*np.exp((-(x-mean1)**2)/(2*sigma1**2)) + a2*np.exp((-(x-mean2)**2)/(2*sigma2**2)) + h
    return fit


#####################
# Fit the data using
# curve fit class
#####################


popt_Ba_133_e1, pcov_Ba_133_e1 = curve_fit(gaus, x_Ba_133[475:575], y_Ba_133[475:575], p0=[a:=1000, mean:=510, sigma:=50, h:=600]) # solves for a, mean, sigma, h
y_Ba_133_fit_e1 = gaus(x_Ba_133, *popt_Ba_133_e1) # creates y(x) = gaus function with fitted values

popt_Ba_133_e2n3, pcov_Ba_133_e2n3 = curve_fit(dODoubleGaus, x_Ba_133_slice_02, y_Ba_133_slice_02, 
                                           p0=[a1:=2500, mean1:=650, sigma1:=100, h:=600, a2:=100, mean2:=775, sigma2:=10]) # solves for a, mean, sigma, h
y_Ba_133_fit_e2n3 = dODoubleGaus(x_Ba_133, *popt_Ba_133_e2n3) # creates y(x) = gaus function with fitted values

popt_Ba_133_e4, pcov_Ba_133_e4 = curve_fit(gaus, x_Ba_133_slice_03, y_Ba_133_slice_03, p0=[a:=20, mean:=1100, sigma:=25, h:=8]) # solves for a, mean, sigma, h
y_Ba_133_fit_e4 = gaus(x_Ba_133, *popt_Ba_133_e4) # creates y(x) = gaus function with fitted values

popt_Ba_133_e5, pcov_Ba_133_e5 = curve_fit(gaus, x_Ba_133[1690:1735], y_Ba_133[1690:1735], p0=[a:=5, mean:=1715, sigma:=10, h:=1]) # solves for a, mean, sigma, h
y_Ba_133_fit_e5 = gaus(x_Ba_133, *popt_Ba_133_e5) # creates y(x) = gaus function with fitted values


#################
# Plot Fit Curve
#################

plt.figure(figsize=(15,10))
plt.plot(x_Ba_133, y_Ba_133, 'o', label="data")
plt.plot(x_Ba_133, y_Ba_133_fit_e1, 'r-', label='E1-fit')
plt.plot(x_Ba_133, y_Ba_133_fit_e2n3, 'r-', label='E2n3-fit')
plt.plot(x_Ba_133, y_Ba_133_fit_e4, 'r-', label='E4-fit')
plt.plot(x_Ba_133, y_Ba_133_fit_e5, 'r-', label='E5-fit')
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Gaussian Plot")
plt.legend()
plt.show()

plt.figure(figsize=(15,10))
plt.plot(x_Ba_133_slice_02, y_Ba_133_slice_02, 'o', label="data")
plt.plot(x_Ba_133, y_Ba_133_fit_e1, 'r-', label='E1_fit')
plt.plot(x_Ba_133, y_Ba_133_fit_e2n3, 'r-', label='E2n3_fit')
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Gaussian Plot (slice)")
plt.legend()
plt.show()

plt.figure(figsize=(15,10))
plt.plot(x_Ba_133_slice_03, y_Ba_133_slice_03, 'o', label="data")
plt.plot(x_Ba_133, y_Ba_133_fit_e4, 'r-', label='E4_fit')
plt.plot(x_Ba_133, y_Ba_133_fit_e5, 'r-', label='E5-fit')
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Gaussian Plot (slice)")
plt.legend()
plt.show()

plt.figure(figsize=(15,10))
plt.plot(x_Ba_133[1600:1800], y_Ba_133[1600:1800], 'o', label="data")
plt.plot(x_Ba_133, y_Ba_133_fit_e5, 'r-', label='E5-fit')
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("Ba-133 Gaussian Plot (slice)")
plt.legend()
plt.show()

# %%
#####################
# Print fit data
# Print uncertainty
#####################

print("Fit Amplitude, Ba-133-E1: ", popt_Ba_133_e1[0],
      "\n Fit Mean, Ba-133-E1: ", popt_Ba_133_e1[1],
      "\n Fit Sigma, Ba-133-E1: ", popt_Ba_133_e1[2],
      "\n Fit Height, Ba-133-E1: ", popt_Ba_133_e1[3])

print("\n Uncertainty matrix, Ba-133-E1: \n", pcov_Ba_133_e1)

print("\n Fit Amplitude, Ba-133-E2: ", popt_Ba_133_e2n3[0],
      "\n Fit Mean, Ba-133-E2: ", popt_Ba_133_e2n3[1],
      "\n Fit Sigma, Ba-133-E2: ", popt_Ba_133_e2n3[2],
      "\n Fit Amplitude, Ba-133-E3: ", popt_Ba_133_e2n3[4],
      "\n Fit Mean, Ba-133-E3: ", popt_Ba_133_e2n3[5],
      "\n Fit Sigma, Ba-133-E3: ", popt_Ba_133_e2n3[6],
      "\n Fit Height, Ba-133-E2n3: ", popt_Ba_133_e2n3[3])

print("\n Uncertainty matrix, Ba-133-E2n3: \n", pcov_Ba_133_e2n3)

print("\n Fit Amplitude, Ba-133-E4: ", popt_Ba_133_e4[0],
      "\n Fit Mean, Ba-133-E4: ", popt_Ba_133_e4[1],
      "\n Fit Sigma, Ba-133-E4: ", popt_Ba_133_e4[2],
      "\n Fit Height, Ba-133-E4: ", popt_Ba_133_e4[3])

print("\n Uncertainty matrix, Ba-133-E4: \n", pcov_Ba_133_e4)

print("\n Fit Amplitude, Ba-133-E5: ", popt_Ba_133_e5[0],
      "\n Fit Mean, Ba-133-E5: ", popt_Ba_133_e5[1],
      "\n Fit Sigma, Ba-133-E5: ", popt_Ba_133_e5[2],
      "\n Fit Height, Ba-133-E5: ", popt_Ba_133_e5[3])

print("\n Uncertainty matrix, Ba-133-E5: \n", pcov_Ba_133_e5)
# Out:
# Fit Amplitude, Ba-133-E1:  515.0776100353052
#  Fit Mean, Ba-133-E1:  530.0438271727832
#  Fit Sigma, Ba-133-E1:  19.0091373769002
#  Fit Height, Ba-133-E1:  559.4409703393536
#
#  Uncertainty matrix, Ba-133-E1:
#  [[ 1.96523047e+02 -2.32150883e-01  4.76618276e+00 -1.48740976e+02]
#  [-2.32150883e-01  1.44728932e-01 -1.01926263e-02  2.67284202e-01]
#  [ 4.76618276e+00 -1.01926263e-02  5.41265623e-01 -8.61936907e+00]
#  [-1.48740976e+02  2.67284202e-01 -8.61936907e+00  1.89337272e+02]]
#
#  Fit Amplitude, Ba-133-E2:  1864.104501684088
#  Fit Mean, Ba-133-E2:  632.9139255106921
#  Fit Sigma, Ba-133-E2:  74.0834382182794
#  Fit Amplitude, Ba-133-E3:  -1032.7412409708295
#  Fit Mean, Ba-133-E3:  701.8293274509119
#  Fit Sigma, Ba-133-E3:  35.74007674458042
#  Fit Height, Ba-133-E2n3:  70.91149785695448
#
#  Uncertainty matrix, Ba-133-E2n3:
#  [[ 9.97073276e+03  5.26339518e+02  1.75350598e+02 -7.60763986e+02
#   -1.49627650e+04 -4.32637539e+01  3.36636198e+02]
#  [ 5.26339518e+02  3.46992958e+01  1.36951368e+01 -4.18048938e+01
#   -9.53275519e+02  1.15633946e+00  1.97034539e+01]
#  [ 1.75350598e+02  1.36951368e+01  9.46265283e+00 -3.73805788e+01
#   -3.95261051e+02  3.18153715e+00  7.21064151e+00]
#  [-7.60763986e+02 -4.18048938e+01 -3.73805788e+01  3.55192859e+02
#    1.25312108e+03 -8.79055399e+00 -1.92440582e+01]
#  [-1.49627650e+04 -9.53275519e+02 -3.95261051e+02  1.25312108e+03
#    2.80325624e+04 -2.97498202e+01 -5.23296024e+02]
#  [-4.32637539e+01  1.15633946e+00  3.18153715e+00 -8.79055399e+00
#   -2.97498202e+01  5.03909372e+00 -4.74652838e-01]
#  [ 3.36636198e+02  1.97034539e+01  7.21064151e+00 -1.92440582e+01
#   -5.23296024e+02 -4.74652838e-01  1.45480929e+01]]
#
#  Fit Amplitude, Ba-133-E4:  8.85034109356783
#  Fit Mean, Ba-133-E4:  1066.8497002788056
#  Fit Sigma, Ba-133-E4:  45.581012958972366
#  Fit Height, Ba-133-E4:  3.0108243376114756
#
#  Uncertainty matrix, Ba-133-E4:
#  [[ 9.93534573e-02  5.78415228e-02 -3.71193660e-01 -4.48677346e-03]
#  [ 5.78415228e-02  3.77352323e+00 -8.86040332e-01 -2.82996601e-03]
#  [-3.71193660e-01 -8.86040332e-01  4.81968838e+00 -3.45529368e-02]
#  [-4.48677346e-03 -2.82996601e-03 -3.45529368e-02  5.62464592e-03]]
#
#  Fit Amplitude, Ba-133-E5:  0.4926552074410491
#  Fit Mean, Ba-133-E5:  1718.2996291335703
#  Fit Sigma, Ba-133-E5:  -7.162722760537967
#  Fit Height, Ba-133-E5:  3.450206925047251
#
#  Uncertainty matrix, Ba-133-E5:
#  [[  0.53720244  -0.25032078  -0.51129761  -0.22500607]
#  [ -0.25032078 102.631354     2.56204482   0.24998279]
#  [ -0.51129761   2.56204482 204.59439913   5.35609157]
#  [ -0.22500607   0.24998279   5.35609157   0.29156598]]
